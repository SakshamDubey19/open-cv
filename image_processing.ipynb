# %%
from PIL import Image,ImageFilter,ImageDraw,ImageFont,ImageEnhance

# %%
im1 = Image.open(r"C:\Users\saksham dubey\Downloads\image2.jpeg")
im1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=319x234>

# %%
im2 = Image.open(r"C:\Users\saksham dubey\Downloads\png image.jpeg")
im2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=159x234>

# %% [markdown]
# # Properties

# %%
print(im1.size)
print(im2.size)
print(im1.width,im1.height)
print(im1.mode)
print(im2.format)
print(im1.format)
# Out:
# (319, 234)
# (159, 234)
# 319 234
# RGB
# JPEG
# JPEG

# %%
w = im1.width
h = im1.height
im1.resize((w//2,h//2))
# Out:
# <PIL.Image.Image image mode=RGB size=159x117>

# %%
im1.resize((int(w*10),int(h*10)))
im1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=319x234>

# %% [markdown]
# # Rotate and Flip

# %%
im1.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=319x234>

# %%
im1.transpose(Image.FLIP_LEFT_RIGHT)
# Out:
# <PIL.Image.Image image mode=RGB size=319x234>

# %%
im1.transpose(Image.FLIP_TOP_BOTTOM)
# Out:
# <PIL.Image.Image image mode=RGB size=319x234>

# %% [markdown]
# # Image Filter

# %%
im2.filter(ImageFilter.EMBOSS)
im1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=319x234>

# %% [markdown]
# # Enhance Image

# %%
en1 = ImageEnhance.Color(im1)
for i in range(-5,6,1):
    en1.enhance(1).show()
en1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 3
#       1 en1 = ImageEnhance.Color(im1)
#       2 for i in range(-5,6,1):
# ----> 3     en1.enhance(1).show()
#       4 en1
#
# File c:\Users\saksham dubey\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\Image.py:2486, in Image.show(self, title)
#    2466 def show(self, title=None):
#    2467     """
#    2468     Displays this image. This method is mainly intended for debugging purposes.
#    2469
#    (...)
#    2483     :param title: Optional title to use for the image window, where possible.
#    2484     """
# -> 2486     _show(self, title=title)
#
# File c:\Users\saksham dubey\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\Image.py:3524, in _show(image, **options)
#    3521 def _show(image, **options):
#    3522     from . import ImageShow
# ...

# %%
en1.degenerate

en2 = ImageEnhance.Contrast(im1)

en2.enhance(2)

# %%
en2.enhance(2)

# %% [markdown]
# # Drawing on Images

# %%
im1 = Image.open(r"C:\Users\saksham dubey\Downloads\image2.jpeg").resize(300,300)
f1 = ImageFont.truetype('f1.TTF',50)
drawim1  = ImageDraw.Draw(im1)
drawim1.text((im1.width//2,100),'Beautifull',
             fill = 'Red',
             font = f1,
             anchor='mm'
             )
drawim1.chord((im1.width//2,100),100,fill='red')
im1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 im1 = Image.open(r"C:\Users\saksham dubey\Downloads\image2.jpeg").resize(300,300)
#       2 f1 = ImageFont.truetype('f1.TTF',50)
#       3 drawim1  = ImageDraw.Draw(im1)
#
# File c:\Users\saksham dubey\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\Image.py:2149, in Image.resize(self, size, resample, box, reducing_gap)
#    2137     filters = [
#    2138         f"{filter[1]} ({filter[0]})"
#    2139         for filter in (
#    (...)
#    2146         )
#    2147     ]
#    2148     msg += " Use " + ", ".join(filters[:-1]) + " or " + filters[-1]
# -> 2149     raise ValueError(msg)
#    2151 if reducing_gap is not None and reducing_gap < 1.0:
#    2152     msg = "reducing_gap must be 1.0 or greater"
#
# ...

# %%
import os
image_list = []
for filename in os.listdir():
